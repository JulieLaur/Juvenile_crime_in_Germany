# %%
import pandas as pd
import numpy as np
from sql_functions import *
import plotly.express as px
import matplotlib.pyplot as plt 
import json
import sqlalchemy
from normal_round import normal_round as normal_round

# %%
pd.set_option('display.max_rows', 6000)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', None) # to show complete content of cell

# %%
df_bund_abs = get_dataframe("SELECT * FROM public.bund_jugend_tat_absolut_2022_until_2018;")
df_bund_rel = get_dataframe("SELECT * FROM public.bund_jugend_tat_relativ_2022_until_2018;")

# %%
df_bund_abs.head()
# Out:
#   schluessel                                                  straftat sexus  \
# 0     ------                                      Straftaten insgesamt     M
# 1     ------                                      Straftaten insgesamt     W
# 2     ------                                      Straftaten insgesamt     X
# 3     100000  Straftaten gegen die sexuelle Selbstbestimmung insgesamt     M
# 4     100000  Straftaten gegen die sexuelle Selbstbestimmung insgesamt     W
#
#    tatverdaechtige_insgesamt  kinder_10_bis_unter_12  kinder_12_bis_unter_14  \
# 0                    1541130                   11882                   25507
# 1                     510136                    4377                   12991
# 2                    2051266                   16259                   38498
# 3                      43036                     310                    1168
# 4                       2500                      76                     309
#
#    kinder_10_bis_unter_14  kinder_unter_14  jugendliche_14_bis_unter_16  \
# 0                   37389            48288                        52244
# 1                   17368            22315                        24451
# 2                   54757            70603                        76695
# 3                    1478             1710                         2861
# 4                     385              408                          339
#
#    jugendliche_16_bis_unter_18  jugendliche_14<18  \
# 0                        76029             128273
# 1                        24707              49158
# 2                       100736             177431
# 3                         2789               5650
# 4                          133                472
#
#    heranwachsende_18_bis_unter_21  jugendl_u_heranwachsende_14_bis_unter_21  \
# 0                          147013                                    275286
# 1                           38510                                     87668
# 2                          185523                                    362954
# 3                            4018                                      9668
# 4                             133                                       605
#
#    erwachsene_ab_21  year
# 0           1217556  2018
# 1            400153  2018
# 2           1617709  2018
# 3             31658  2018
# 4              1487  2018

# %%
# delete Mord and Totschlag as seperate keys; delete seperate Nötigungs keys (Nötigung summarized kept)
relevant_keys = ["------", "010000, 020010", "220000", "100000", "232100", "232200", "435*00", "*26*00", "210000", "730000", "891100", "674000"]

# %%
# merge absolute and relative 
df_bund_abs_rel = df_bund_abs.merge(df_bund_rel, on=['schluessel', "straftat", 'sexus', 'year'], how='left')

# keep only relevant keys
df_bund_abs_rel = df_bund_abs_rel[df_bund_abs_rel['schluessel'].isin(relevant_keys)]

# filter for relevant columns and bring them in correct order
df_bund_abs_rel = df_bund_abs_rel[['schluessel', 'straftat', 'year', 'sexus',
                                         'jugendliche_14_bis_unter_16', 'jugendliche_16_bis_unter_18', 'heranwachsende_18_bis_unter_21',
                                         'jugendl_u_heranwachsende_14_bis_unter_21',
                                         'jugendliche_14_bis_unter_16_rel', 'jugendliche_16_bis_unter_18_rel', 'heranwachsende_18_bis_unter_21_rel',
                                         'jugendl_u_heranwachsende_14_bis_unter_21_rel']]

df_bund_abs_rel.head()
# Out:
#   schluessel                                                  straftat  year  \
# 0     ------                                      Straftaten insgesamt  2018
# 1     ------                                      Straftaten insgesamt  2018
# 2     ------                                      Straftaten insgesamt  2018
# 3     100000  Straftaten gegen die sexuelle Selbstbestimmung insgesamt  2018
# 4     100000  Straftaten gegen die sexuelle Selbstbestimmung insgesamt  2018
#
#   sexus  jugendliche_14_bis_unter_16  jugendliche_16_bis_unter_18  \
# 0     M                        52244                        76029
# 1     W                        24451                        24707
# 2     X                        76695                       100736
# 3     M                         2861                         2789
# 4     W                          339                          133
#
#    heranwachsende_18_bis_unter_21  jugendl_u_heranwachsende_14_bis_unter_21  \
# 0                          147013                                    275286
# 1                           38510                                     87668
# 2                          185523                                    362954
# 3                            4018                                      9668
# 4                             133                                       605
#
#    jugendliche_14_bis_unter_16_rel  jugendliche_16_bis_unter_18_rel  \
# 0                      6723.489358                      9104.833301
# 1                      3347.484834                      3204.086582
# 2                      5087.676936                      6271.896318
# 3                       368.193535                       333.995976
# 4                        46.411082                        17.247886
#
#    heranwachsende_18_bis_unter_21_rel  \
# 0                        10596.073745
# 1                         3093.383886
# 2                         7047.825056
# 3                          289.600405
# 4                           10.683460
#
#    jugendl_u_heranwachsende_14_bis_unter_21_rel
# 0                                   9177.711263
# 1                                   3192.044430
# 2                                   6316.682733
# 3                                    322.319742
# 4                                     22.028413

# %%
# round relative numbers
columns = ['jugendliche_14_bis_unter_16_rel', 'jugendliche_16_bis_unter_18_rel', 'heranwachsende_18_bis_unter_21_rel', 'jugendl_u_heranwachsende_14_bis_unter_21_rel']

for col in columns: 
    new_values = []
    globals()[f'values_{col}'] = df_bund_abs_rel[col].tolist()
    for v in globals()[f'values_{col}']:
        new_v = int(normal_round(v))
        new_values.append(new_v)
    df_bund_abs_rel[col] = new_values

df_bund_abs_rel.head()
# Out:
#   schluessel                                                  straftat  year  \
# 0     ------                                      Straftaten insgesamt  2018
# 1     ------                                      Straftaten insgesamt  2018
# 2     ------                                      Straftaten insgesamt  2018
# 3     100000  Straftaten gegen die sexuelle Selbstbestimmung insgesamt  2018
# 4     100000  Straftaten gegen die sexuelle Selbstbestimmung insgesamt  2018
#
#   sexus  jugendliche_14_bis_unter_16  jugendliche_16_bis_unter_18  \
# 0     M                        52244                        76029
# 1     W                        24451                        24707
# 2     X                        76695                       100736
# 3     M                         2861                         2789
# 4     W                          339                          133
#
#    heranwachsende_18_bis_unter_21  jugendl_u_heranwachsende_14_bis_unter_21  \
# 0                          147013                                    275286
# 1                           38510                                     87668
# 2                          185523                                    362954
# 3                            4018                                      9668
# 4                             133                                       605
#
#    jugendliche_14_bis_unter_16_rel  jugendliche_16_bis_unter_18_rel  \
# 0                             6723                             9105
# 1                             3347                             3204
# 2                             5088                             6272
# 3                              368                              334
# 4                               46                               17
#
#    heranwachsende_18_bis_unter_21_rel  \
# 0                               10596
# 1                                3093
# 2                                7048
# 3                                 290
# 4                                  11
#
#    jugendl_u_heranwachsende_14_bis_unter_21_rel
# 0                                          9178
# 1                                          3192
# 2                                          6317
# 3                                           322
# 4                                            22

# %%
df_1 = df_bund_abs_rel.copy()
df_1 = df_1[["schluessel", "straftat",  "year", 'sexus', "jugendliche_14_bis_unter_16", "jugendliche_16_bis_unter_18", "heranwachsende_18_bis_unter_21", "jugendl_u_heranwachsende_14_bis_unter_21", "jugendliche_14_bis_unter_16_rel", "jugendliche_16_bis_unter_18_rel", "heranwachsende_18_bis_unter_21_rel", "jugendl_u_heranwachsende_14_bis_unter_21_rel"]]

df_4 = pd.DataFrame(columns = ["schluessel", "straftat", "year", 'sexus', "jugendliche_14_bis_unter_16", "jugendliche_16_bis_unter_18", "heranwachsende_18_bis_unter_21", "jugendl_u_heranwachsende_14_bis_unter_21", "jugendliche_14_bis_unter_16_rel", "jugendliche_16_bis_unter_18_rel", "heranwachsende_18_bis_unter_21_rel", "jugendl_u_heranwachsende_14_bis_unter_21_rel", "growth_rate_abs_14_<_16", "growth_rate_abs_16_<_18", "growth_rate_abs_18_<_21", "growth_rate_abs_14_<_21", "growth_rate_rel_14_<_16", "growth_rate_rel_16_<_18", "growth_rate_rel_18_<_21", "growth_rate_rel_14_<_21"])

gender = ['X', 'W', 'M']
schluessel = ["------", "010000, 020010", "220000", "100000", "232100", "232200", "435*00", "*26*00", "210000", "730000", "891100", "674000"]

for g in gender:
    df_2 = df_1[df_1["sexus"] == g]
    for s in schluessel:
        df_3 = df_2[df_2["schluessel"] == s]
        df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
        df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
        df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
        df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
        df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
        df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
        df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
        df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
        df_4 = pd.concat([df_4, df_3])

df_bund_growth_rate_abs_rel = df_4.copy()
df_bund_growth_rate_abs_rel.head(10)
# Out:
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_16"] = df_3["jugendliche_14_bis_unter_16"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_16_<_18"] = df_3["jugendliche_16_bis_unter_18"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_18_<_21"] = df_3["heranwachsende_18_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_abs_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_16"] = df_3["jugendliche_14_bis_unter_16_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_16_<_18"] = df_3["jugendliche_16_bis_unter_18_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_18_<_21"] = df_3["heranwachsende_18_bis_unter_21_rel"].pct_change() * 100
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/2460071674.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["growth_rate_rel_14_<_21"] = df_3["jugendl_u_heranwachsende_14_bis_unter_21_rel"].pct_change() * 100
#          schluessel                             straftat  year sexus  \
# 2            ------                 Straftaten insgesamt  2018     X
# 35           ------                 Straftaten insgesamt  2019     X
# 68           ------                 Straftaten insgesamt  2020     X
# 101          ------                 Straftaten insgesamt  2021     X
# 134          ------                 Straftaten insgesamt  2022     X
# 167  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2018     X
# 170  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2019     X
# 173  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2020     X
# 176  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2021     X
# 179  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2022     X
#
#     jugendliche_14_bis_unter_16 jugendliche_16_bis_unter_18  \
# 2                         76695                      100736
# 35                        79862                       97220
# 68                        72218                       90746
# 101                       69469                       85420
# 134                       91087                       98062
# 167                          33                         127
# 170                          47                         109
# 173                          35                         105
# 176                          58                         115
# 179                          59                         137
#
#     heranwachsende_18_bis_unter_21 jugendl_u_heranwachsende_14_bis_unter_21  \
# 2                           185523                                   362954
# 35                          177774                                   354856
# 68                          166033                                   328997
# 101                         150865                                   305754
# 134                         160998                                   350147
# 167                            342                                      502
# 170                            369                                      525
# 173                            289                                      429
# 176                            285                                      458
# 179                            297                                      493
#
#     jugendliche_14_bis_unter_16_rel jugendliche_16_bis_unter_18_rel  \
# 2                              5088                            6272
# 35                             5310                            6255
# 68                             4823                            5932
# 101                            4696                            5613
# 134                            6093                            6467
# 167                               2                               8
# 170                               3                               7
# 173                               2                               7
# 176                               4                               8
# 179                               4                               9
#
#     heranwachsende_18_bis_unter_21_rel  \
# 2                                 7048
# 35                                6868
# 68                                6559
# 101                               6141
# 134                               6702
# 167                                 13
# 170                                 14
# 173                                 11
# 176                                 12
# 179                                 12
#
#     jugendl_u_heranwachsende_14_bis_unter_21_rel  growth_rate_abs_14_<_16  \
# 2                                           6317                      NaN
# 35                                          6284                 4.129344
# 68                                          5919                -9.571511
# 101                                         5602                -3.806530
# 134                                         6468                31.118916
# 167                                            9                      NaN
# 170                                            9                42.424242
# 173                                            8               -25.531915
# 176                                            8                65.714286
# 179                                            9                 1.724138
#
#      growth_rate_abs_16_<_18  growth_rate_abs_18_<_21  \
# 2                        NaN                      NaN
# 35                 -3.490311                -4.176841
# 68                 -6.659124                -6.604453
# 101                -5.869129                -9.135533
# 134                14.799813                 6.716601
# 167                      NaN                      NaN
# 170               -14.173228                 7.894737
# 173                -3.669725               -21.680217
# 176                 9.523810                -1.384083
# 179                19.130435                 4.210526
#
#      growth_rate_abs_14_<_21  growth_rate_rel_14_<_16  \
# 2                        NaN                      NaN
# 35                 -2.231137                 4.363208
# 68                 -7.287181                -9.171375
# 101                -7.064806                -2.633216
# 134                14.519189                29.748722
# 167                      NaN                      NaN
# 170                 4.581673                50.000000
# 173               -18.285714               -33.333333
# 176                 6.759907               100.000000
# 179                 7.641921                 0.000000
#
#      growth_rate_rel_16_<_18  growth_rate_rel_18_<_21  growth_rate_rel_14_<_21
# 2                        NaN                      NaN                      NaN
# 35                 -0.271046                -2.553916                -0.522400
# 68                 -5.163869                -4.499126                -5.808402
# 101                -5.377613                -6.372923                -5.355634
# 134                15.214680                 9.135320                15.458765
# 167                      NaN                      NaN                      NaN
# 170               -12.500000                 7.692308                 0.000000
# 173                 0.000000               -21.428571               -11.111111
# 176                14.285714                 9.090909                 0.000000
# 179                12.500000                 0.000000                12.500000

# %%
columns = ["growth_rate_abs_14_<_16", "growth_rate_abs_16_<_18", "growth_rate_abs_18_<_21", "growth_rate_abs_14_<_21", "growth_rate_rel_14_<_16", "growth_rate_rel_16_<_18", "growth_rate_rel_18_<_21", "growth_rate_rel_14_<_21"]
df_bund_growth_rate_abs_rel[columns] = df_bund_growth_rate_abs_rel[columns].applymap(lambda x: np.nan if np.isnan(x) or np.isinf(x) else normal_round(x, 2))
df_bund_growth_rate_abs_rel.head()
# Out:
#     schluessel              straftat  year sexus jugendliche_14_bis_unter_16  \
# 2       ------  Straftaten insgesamt  2018     X                       76695
# 35      ------  Straftaten insgesamt  2019     X                       79862
# 68      ------  Straftaten insgesamt  2020     X                       72218
# 101     ------  Straftaten insgesamt  2021     X                       69469
# 134     ------  Straftaten insgesamt  2022     X                       91087
#
#     jugendliche_16_bis_unter_18 heranwachsende_18_bis_unter_21  \
# 2                        100736                         185523
# 35                        97220                         177774
# 68                        90746                         166033
# 101                       85420                         150865
# 134                       98062                         160998
#
#     jugendl_u_heranwachsende_14_bis_unter_21 jugendliche_14_bis_unter_16_rel  \
# 2                                     362954                            5088
# 35                                    354856                            5310
# 68                                    328997                            4823
# 101                                   305754                            4696
# 134                                   350147                            6093
#
#     jugendliche_16_bis_unter_18_rel heranwachsende_18_bis_unter_21_rel  \
# 2                              6272                               7048
# 35                             6255                               6868
# 68                             5932                               6559
# 101                            5613                               6141
# 134                            6467                               6702
#
#     jugendl_u_heranwachsende_14_bis_unter_21_rel  growth_rate_abs_14_<_16  \
# 2                                           6317                      NaN
# 35                                          6284                     4.13
# 68                                          5919                    -9.56
# 101                                         5602                    -3.80
# 134                                         6468                    31.12
#
#      growth_rate_abs_16_<_18  growth_rate_abs_18_<_21  \
# 2                        NaN                      NaN
# 35                     -3.48                    -4.17
# 68                     -6.65                    -6.59
# 101                    -5.86                    -9.13
# 134                    14.80                     6.72
#
#      growth_rate_abs_14_<_21  growth_rate_rel_14_<_16  \
# 2                        NaN                      NaN
# 35                     -2.22                     4.36
# 68                     -7.28                    -9.16
# 101                    -7.05                    -2.62
# 134                    14.52                    29.75
#
#      growth_rate_rel_16_<_18  growth_rate_rel_18_<_21  growth_rate_rel_14_<_21
# 2                        NaN                      NaN                      NaN
# 35                     -0.26                    -2.54                    -0.51
# 68                     -5.15                    -4.49                    -5.80
# 101                    -5.37                    -6.36                    -5.35
# 134                    15.21                     9.14                    15.46

# %%
#Drop columns
df_bund_growth_rate_abs_rel = df_bund_growth_rate_abs_rel.drop(columns = ['jugendliche_14_bis_unter_16', 'jugendliche_16_bis_unter_18', 'heranwachsende_18_bis_unter_21','jugendl_u_heranwachsende_14_bis_unter_21', 'jugendliche_14_bis_unter_16_rel', 'jugendliche_16_bis_unter_18_rel', 'heranwachsende_18_bis_unter_21_rel', 'jugendl_u_heranwachsende_14_bis_unter_21_rel'])
df_bund_growth_rate_abs_rel.head(10)
# Out:
#          schluessel                             straftat  year sexus  \
# 2            ------                 Straftaten insgesamt  2018     X
# 35           ------                 Straftaten insgesamt  2019     X
# 68           ------                 Straftaten insgesamt  2020     X
# 101          ------                 Straftaten insgesamt  2021     X
# 134          ------                 Straftaten insgesamt  2022     X
# 167  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2018     X
# 170  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2019     X
# 173  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2020     X
# 176  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2021     X
# 179  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2022     X
#
#      growth_rate_abs_14_<_16  growth_rate_abs_16_<_18  \
# 2                        NaN                      NaN
# 35                      4.13                    -3.48
# 68                     -9.56                    -6.65
# 101                    -3.80                    -5.86
# 134                    31.12                    14.80
# 167                      NaN                      NaN
# 170                    42.42                   -14.16
# 173                   -25.52                    -3.66
# 176                    65.71                     9.52
# 179                     1.72                    19.13
#
#      growth_rate_abs_18_<_21  growth_rate_abs_14_<_21  \
# 2                        NaN                      NaN
# 35                     -4.17                    -2.22
# 68                     -6.59                    -7.28
# 101                    -9.13                    -7.05
# 134                     6.72                    14.52
# 167                      NaN                      NaN
# 170                     7.89                     4.58
# 173                   -21.67                   -18.28
# 176                    -1.37                     6.76
# 179                     4.21                     7.64
#
#      growth_rate_rel_14_<_16  growth_rate_rel_16_<_18  \
# 2                        NaN                      NaN
# 35                      4.36                    -0.26
# 68                     -9.16                    -5.15
# 101                    -2.62                    -5.37
# 134                    29.75                    15.21
# 167                      NaN                      NaN
# 170                    50.00                   -12.49
# 173                   -33.32                     0.00
# 176                   100.00                    14.29
# 179                     0.00                    12.50
#
#      growth_rate_rel_18_<_21  growth_rate_rel_14_<_21
# 2                        NaN                      NaN
# 35                     -2.54                    -0.51
# 68                     -4.49                    -5.80
# 101                    -6.36                    -5.35
# 134                     9.14                    15.46
# 167                      NaN                      NaN
# 170                     7.69                     0.00
# 173                   -21.42                   -11.10
# 176                     9.09                     0.00
# 179                     0.00                    12.50

# %%
df_spl1 = df_bund_growth_rate_abs_rel[["schluessel", "straftat", "year", 'sexus','growth_rate_abs_14_<_16', 'growth_rate_rel_14_<_16']]
df_spl1['age_group'] = 'jugendliche_14_bis_unter_16'
df_spl1 = df_spl1.rename(columns = {'growth_rate_abs_14_<_16': 'growth_rate_abs'})
df_spl1 = df_spl1.rename(columns = {'growth_rate_rel_14_<_16': 'growth_rate_rel'})

df_spl2 = df_bund_growth_rate_abs_rel[["schluessel", "straftat", "year", 'sexus','growth_rate_abs_16_<_18', 'growth_rate_rel_16_<_18']]
df_spl2['age_group'] = 'jugendliche_16_bis_unter_18'
df_spl2 = df_spl2.rename(columns = {'growth_rate_abs_16_<_18': 'growth_rate_abs'})
df_spl2 = df_spl2.rename(columns = {'growth_rate_rel_16_<_18': 'growth_rate_rel'})

df_spl3 = df_bund_growth_rate_abs_rel[["schluessel", "straftat", "year", 'sexus','growth_rate_abs_18_<_21','growth_rate_rel_18_<_21']]
df_spl3['age_group'] = 'heranwachsende_18_bis_unter_21'
df_spl3 = df_spl3.rename(columns = {'growth_rate_abs_18_<_21': 'growth_rate_abs'})
df_spl3 = df_spl3.rename(columns = {'growth_rate_rel_18_<_21': 'growth_rate_rel'})

df_spl4 = df_bund_growth_rate_abs_rel[["schluessel", "straftat", "year", 'sexus','growth_rate_abs_14_<_21', 'growth_rate_rel_14_<_21']]
df_spl4['age_group'] = 'jugendl_u_heranwachsende_14_bis_unter_21'
df_spl4 = df_spl4.rename(columns = {'growth_rate_abs_14_<_21': 'growth_rate_abs'})
df_spl4 = df_spl4.rename(columns = {'growth_rate_rel_14_<_21': 'growth_rate_rel'})
df_spl4.head()
# Out:
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/3581319576.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_spl1['age_group'] = 'jugendliche_14_bis_unter_16'
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/3581319576.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_spl2['age_group'] = 'jugendliche_16_bis_unter_18'
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/3581319576.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_spl3['age_group'] = 'heranwachsende_18_bis_unter_21'
# /var/folders/fz/x58kn2h9163grc3hjfj_f25r0000gn/T/ipykernel_88369/3581319576.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_spl4['age_group'] = 'jugendl_u_heranwachsende_14_bis_unter_21'
#     schluessel              straftat  year sexus  growth_rate_abs  \
# 2       ------  Straftaten insgesamt  2018     X              NaN
# 35      ------  Straftaten insgesamt  2019     X            -2.22
# 68      ------  Straftaten insgesamt  2020     X            -7.28
# 101     ------  Straftaten insgesamt  2021     X            -7.05
# 134     ------  Straftaten insgesamt  2022     X            14.52
#
#      growth_rate_rel                                 age_group
# 2                NaN  jugendl_u_heranwachsende_14_bis_unter_21
# 35             -0.51  jugendl_u_heranwachsende_14_bis_unter_21
# 68             -5.80  jugendl_u_heranwachsende_14_bis_unter_21
# 101            -5.35  jugendl_u_heranwachsende_14_bis_unter_21
# 134            15.46  jugendl_u_heranwachsende_14_bis_unter_21

# %%
df_bund_growth_rate_abs_rel = pd.concat([df_spl1, df_spl2, df_spl3, df_spl4])
df_bund_growth_rate_abs_rel = df_bund_growth_rate_abs_rel.reset_index()
df_bund_growth_rate_abs_rel = df_bund_growth_rate_abs_rel.drop(columns = 'index')
df_bund_growth_rate_abs_rel.head()
# Out:
#   schluessel              straftat  year sexus  growth_rate_abs  \
# 0     ------  Straftaten insgesamt  2018     X              NaN
# 1     ------  Straftaten insgesamt  2019     X             4.13
# 2     ------  Straftaten insgesamt  2020     X            -9.56
# 3     ------  Straftaten insgesamt  2021     X            -3.80
# 4     ------  Straftaten insgesamt  2022     X            31.12
#
#    growth_rate_rel                    age_group
# 0              NaN  jugendliche_14_bis_unter_16
# 1             4.36  jugendliche_14_bis_unter_16
# 2            -9.16  jugendliche_14_bis_unter_16
# 3            -2.62  jugendliche_14_bis_unter_16
# 4            29.75  jugendliche_14_bis_unter_16

# %%
# Add new column to the DataFrame
bundesland = 'Bundesrepublik-Deutschland'
df_bund_growth_rate_abs_rel = df_bund_growth_rate_abs_rel.assign(bundesland=bundesland)
df_bund_growth_rate_abs_rel.head(10)
# Out:
#        schluessel                             straftat  year sexus  \
# 0          ------                 Straftaten insgesamt  2018     X
# 1          ------                 Straftaten insgesamt  2019     X
# 2          ------                 Straftaten insgesamt  2020     X
# 3          ------                 Straftaten insgesamt  2021     X
# 4          ------                 Straftaten insgesamt  2022     X
# 5  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2018     X
# 6  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2019     X
# 7  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2020     X
# 8  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2021     X
# 9  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  2022     X
#
#    growth_rate_abs  growth_rate_rel                    age_group  \
# 0              NaN              NaN  jugendliche_14_bis_unter_16
# 1             4.13             4.36  jugendliche_14_bis_unter_16
# 2            -9.56            -9.16  jugendliche_14_bis_unter_16
# 3            -3.80            -2.62  jugendliche_14_bis_unter_16
# 4            31.12            29.75  jugendliche_14_bis_unter_16
# 5              NaN              NaN  jugendliche_14_bis_unter_16
# 6            42.42            50.00  jugendliche_14_bis_unter_16
# 7           -25.52           -33.32  jugendliche_14_bis_unter_16
# 8            65.71           100.00  jugendliche_14_bis_unter_16
# 9             1.72             0.00  jugendliche_14_bis_unter_16
#
#                    bundesland
# 0  Bundesrepublik-Deutschland
# 1  Bundesrepublik-Deutschland
# 2  Bundesrepublik-Deutschland
# 3  Bundesrepublik-Deutschland
# 4  Bundesrepublik-Deutschland
# 5  Bundesrepublik-Deutschland
# 6  Bundesrepublik-Deutschland
# 7  Bundesrepublik-Deutschland
# 8  Bundesrepublik-Deutschland
# 9  Bundesrepublik-Deutschland

# %%
df_bund_growth_rate_abs_rel = df_bund_growth_rate_abs_rel[['schluessel', 'straftat', 'bundesland', 'year', 'sexus', 'age_group', 'growth_rate_abs', 'growth_rate_rel']]
df_bund_growth_rate_abs_rel.head(10)
# Out:
#        schluessel                             straftat  \
# 0          ------                 Straftaten insgesamt
# 1          ------                 Straftaten insgesamt
# 2          ------                 Straftaten insgesamt
# 3          ------                 Straftaten insgesamt
# 4          ------                 Straftaten insgesamt
# 5  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
# 6  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
# 7  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
# 8  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
# 9  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
#
#                    bundesland  year sexus                    age_group  \
# 0  Bundesrepublik-Deutschland  2018     X  jugendliche_14_bis_unter_16
# 1  Bundesrepublik-Deutschland  2019     X  jugendliche_14_bis_unter_16
# 2  Bundesrepublik-Deutschland  2020     X  jugendliche_14_bis_unter_16
# 3  Bundesrepublik-Deutschland  2021     X  jugendliche_14_bis_unter_16
# 4  Bundesrepublik-Deutschland  2022     X  jugendliche_14_bis_unter_16
# 5  Bundesrepublik-Deutschland  2018     X  jugendliche_14_bis_unter_16
# 6  Bundesrepublik-Deutschland  2019     X  jugendliche_14_bis_unter_16
# 7  Bundesrepublik-Deutschland  2020     X  jugendliche_14_bis_unter_16
# 8  Bundesrepublik-Deutschland  2021     X  jugendliche_14_bis_unter_16
# 9  Bundesrepublik-Deutschland  2022     X  jugendliche_14_bis_unter_16
#
#    growth_rate_abs  growth_rate_rel
# 0              NaN              NaN
# 1             4.13             4.36
# 2            -9.56            -9.16
# 3            -3.80            -2.62
# 4            31.12            29.75
# 5              NaN              NaN
# 6            42.42            50.00
# 7           -25.52           -33.32
# 8            65.71           100.00
# 9             1.72             0.00

# %%
# Concat df_bund_growth_rate_abs_rel with df_laender_growth_rate_abs_rel
# First: store df_laender_growth_rate_abs_rel
# %store -r df_laender_growth_rate_abs_rel

# %%
df_laender_growth_rate_abs_rel.head(10)
# Out:
#   schluessel                           straftat bundesland  year sexus  \
# 0     674000  Sachbeschädigung §§ 303-305a StGB  Thüringen  2018     M
# 1     674000  Sachbeschädigung §§ 303-305a StGB  Thüringen  2019     M
# 2     674000  Sachbeschädigung §§ 303-305a StGB  Thüringen  2020     M
# 3     674000  Sachbeschädigung §§ 303-305a StGB  Thüringen  2021     M
# 4     674000  Sachbeschädigung §§ 303-305a StGB  Thüringen  2022     M
# 5     891100   direkte Beschaffungskriminalität  Thüringen  2018     M
# 6     891100   direkte Beschaffungskriminalität  Thüringen  2019     M
# 7     891100   direkte Beschaffungskriminalität  Thüringen  2020     M
# 8     891100   direkte Beschaffungskriminalität  Thüringen  2021     M
# 9     891100   direkte Beschaffungskriminalität  Thüringen  2022     M
#
#                      age_group  growth_rate_abs  growth_rate_rel
# 0  jugendliche_14_bis_unter_16              NaN              NaN
# 1  jugendliche_14_bis_unter_16            -7.94            -9.82
# 2  jugendliche_14_bis_unter_16            -0.81            -1.02
# 3  jugendliche_14_bis_unter_16            -4.97            -3.49
# 4  jugendliche_14_bis_unter_16             5.68             2.16
# 5  jugendliche_14_bis_unter_16              NaN              NaN
# 6  jugendliche_14_bis_unter_16              NaN              NaN
# 7  jugendliche_14_bis_unter_16              NaN              NaN
# 8  jugendliche_14_bis_unter_16              NaN              NaN
# 9  jugendliche_14_bis_unter_16              NaN              NaN

# %%
df_overview_states_growth_rate = pd.concat([df_bund_growth_rate_abs_rel, df_laender_growth_rate_abs_rel])
df_overview_states_growth_rate = df_overview_states_growth_rate.reset_index()
df_overview_states_growth_rate = df_overview_states_growth_rate.drop(columns='index')
df_overview_states_growth_rate.head()
# Out:
#   schluessel              straftat                  bundesland  year sexus  \
# 0     ------  Straftaten insgesamt  Bundesrepublik-Deutschland  2018     X
# 1     ------  Straftaten insgesamt  Bundesrepublik-Deutschland  2019     X
# 2     ------  Straftaten insgesamt  Bundesrepublik-Deutschland  2020     X
# 3     ------  Straftaten insgesamt  Bundesrepublik-Deutschland  2021     X
# 4     ------  Straftaten insgesamt  Bundesrepublik-Deutschland  2022     X
#
#                      age_group  growth_rate_abs  growth_rate_rel
# 0  jugendliche_14_bis_unter_16              NaN              NaN
# 1  jugendliche_14_bis_unter_16             4.13             4.36
# 2  jugendliche_14_bis_unter_16            -9.56            -9.16
# 3  jugendliche_14_bis_unter_16            -3.80            -2.62
# 4  jugendliche_14_bis_unter_16            31.12            29.75

# %%
df_overview_states_growth_rate.tail(10)
# Out:
#            schluessel                             straftat         bundesland  \
# 12230  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  Baden-Württemberg
# 12231  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  Baden-Württemberg
# 12232  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  Baden-Württemberg
# 12233  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  Baden-Württemberg
# 12234  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB  Baden-Württemberg
# 12235          ------                 Straftaten insgesamt  Baden-Württemberg
# 12236          ------                 Straftaten insgesamt  Baden-Württemberg
# 12237          ------                 Straftaten insgesamt  Baden-Württemberg
# 12238          ------                 Straftaten insgesamt  Baden-Württemberg
# 12239          ------                 Straftaten insgesamt  Baden-Württemberg
#
#        year sexus                                 age_group  growth_rate_abs  \
# 12230  2018     X  jugendl_u_heranwachsende_14_bis_unter_21              NaN
# 12231  2019     X  jugendl_u_heranwachsende_14_bis_unter_21            -5.80
# 12232  2020     X  jugendl_u_heranwachsende_14_bis_unter_21           -16.04
# 12233  2021     X  jugendl_u_heranwachsende_14_bis_unter_21            27.94
# 12234  2022     X  jugendl_u_heranwachsende_14_bis_unter_21           -11.48
# 12235  2018     X  jugendl_u_heranwachsende_14_bis_unter_21              NaN
# 12236  2019     X  jugendl_u_heranwachsende_14_bis_unter_21            -3.40
# 12237  2020     X  jugendl_u_heranwachsende_14_bis_unter_21            -9.47
# 12238  2021     X  jugendl_u_heranwachsende_14_bis_unter_21            -9.31
# 12239  2022     X  jugendl_u_heranwachsende_14_bis_unter_21            13.05
#
#        growth_rate_rel
# 12230              NaN
# 12231             0.00
# 12232            -9.99
# 12233            22.22
# 12234            -9.08
# 12235              NaN
# 12236            -1.08
# 12237            -7.63
# 12238            -7.13
# 12239            14.36

# %%
df_overview_states_growth_rate.shape
# Out:
# (12240, 8)

# %%
df_overview_states_growth_rate = df_overview_states_growth_rate.fillna('n.a.')
df_overview_states_growth_rate.head(10)
# Out:
#        schluessel                             straftat  \
# 0          ------                 Straftaten insgesamt
# 1          ------                 Straftaten insgesamt
# 2          ------                 Straftaten insgesamt
# 3          ------                 Straftaten insgesamt
# 4          ------                 Straftaten insgesamt
# 5  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
# 6  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
# 7  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
# 8  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
# 9  010000, 020010  Mord § 211 StGBTotschlag § 212 StGB
#
#                    bundesland  year sexus                    age_group  \
# 0  Bundesrepublik-Deutschland  2018     X  jugendliche_14_bis_unter_16
# 1  Bundesrepublik-Deutschland  2019     X  jugendliche_14_bis_unter_16
# 2  Bundesrepublik-Deutschland  2020     X  jugendliche_14_bis_unter_16
# 3  Bundesrepublik-Deutschland  2021     X  jugendliche_14_bis_unter_16
# 4  Bundesrepublik-Deutschland  2022     X  jugendliche_14_bis_unter_16
# 5  Bundesrepublik-Deutschland  2018     X  jugendliche_14_bis_unter_16
# 6  Bundesrepublik-Deutschland  2019     X  jugendliche_14_bis_unter_16
# 7  Bundesrepublik-Deutschland  2020     X  jugendliche_14_bis_unter_16
# 8  Bundesrepublik-Deutschland  2021     X  jugendliche_14_bis_unter_16
# 9  Bundesrepublik-Deutschland  2022     X  jugendliche_14_bis_unter_16
#
#   growth_rate_abs growth_rate_rel
# 0            n.a.            n.a.
# 1            4.13            4.36
# 2           -9.56           -9.16
# 3            -3.8           -2.62
# 4           31.12           29.75
# 5            n.a.            n.a.
# 6           42.42            50.0
# 7          -25.52          -33.32
# 8           65.71           100.0
# 9            1.72             0.0

# %%
schema='public'
table_name = 'df_growth_rate_2022_until_2018'
engine = get_engine()
print(engine)
# Out:
# Engine(postgresql://user:***@host/database)

# %%
if engine!=None:
    try:
        df_overview_states_growth_rate.to_sql(table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists='replace', # Drop the table before inserting new values 
                        schema=schema, # your class schema
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The df_growth_rate_2022_until_2018 table was imported successfully.
