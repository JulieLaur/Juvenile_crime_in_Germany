# %%
import pandas as pd
import numpy as np
from sql_functions import *
from normal_round import normal_round as normal_round

# %%
pd.set_option('display.max_rows', 6000)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', None)

# %%
# %store -r df_overview_state_14_to_under_16
# %store -r df_overview_state_16_to_under_18
# %store -r df_overview_state_18_to_under_21
# %store -r df_overview_state_14_to_under_21

# %%
df_overview_state_14_to_under_16.head()
# Out:
#    year sexus                    age_group  offenders  offenders_rel  \
# 0  2018     M  jugendliche_14_bis_unter_16      52244           6723
# 1  2018     W  jugendliche_14_bis_unter_16      24451           3347
# 2  2018     X  jugendliche_14_bis_unter_16      76695           5088
# 3  2019     M  jugendliche_14_bis_unter_16      54636           7059
# 4  2019     W  jugendliche_14_bis_unter_16      25226           3456
#
#   growth_rate_abs growth_rate_rel schluessel_crimes_on_rank_1  \
# 0            n.a.            n.a.                      220000
# 1            n.a.            n.a.                      *26*00
# 2            n.a.            n.a.                      *26*00
# 3            4.58            4.99                      220000
# 4            3.17            3.23                      *26*00
#
#                              crimes_on_rank_1  \
# 0  Körperverletzung §§ 223-227, 229, 231 StGB
# 1                    Ladendiebstahl insgesamt
# ...

# %%
df_overview_state_16_to_under_18.head()
# Out:
#    year sexus                    age_group  offenders  offenders_rel  \
# 0  2018     M  jugendliche_16_bis_unter_18      76029           9105
# 1  2018     W  jugendliche_16_bis_unter_18      24707           3204
# 2  2018     X  jugendliche_16_bis_unter_18     100736           6272
# 3  2019     M  jugendliche_16_bis_unter_18      73445           9126
# 4  2019     W  jugendliche_16_bis_unter_18      23775           3172
#
#   growth_rate_abs growth_rate_rel schluessel_crimes_on_rank_1  \
# 0            n.a.            n.a.                      730000
# 1            n.a.            n.a.                      *26*00
# 2            n.a.            n.a.                      730000
# 3           -3.39            0.23                      730000
# 4           -3.76           -0.98                      *26*00
#
#                                                              crimes_on_rank_1  \
# 0  Rauschgiftdelikte (soweit nicht bereits mit anderer Schlüsselzahl erfasst)
# ...

# %%
df_overview_state_18_to_under_21.head()
# Out:
#    year sexus                       age_group  offenders  offenders_rel  \
# 0  2018     M  heranwachsende_18_bis_unter_21     147013          10596
# 1  2018     W  heranwachsende_18_bis_unter_21      38510           3093
# 2  2018     X  heranwachsende_18_bis_unter_21     185523           7048
# 3  2019     M  heranwachsende_18_bis_unter_21     140338          10331
# 4  2019     W  heranwachsende_18_bis_unter_21      37436           3043
#
#   growth_rate_abs growth_rate_rel schluessel_crimes_on_rank_1  \
# 0            n.a.            n.a.                      730000
# 1            n.a.            n.a.                      220000
# 2            n.a.            n.a.                      730000
# 3           -4.53           -2.49                      730000
# 4           -2.78           -1.61                      220000
#
#                                                              crimes_on_rank_1  \
# ...

# %%
df_overview_state_14_to_under_21.head()
# Out:
#    year sexus                                 age_group  offenders  \
# 0  2018     M  jugendl_u_heranwachsende_14_bis_unter_21     275286
# 1  2018     W  jugendl_u_heranwachsende_14_bis_unter_21      87668
# 2  2018     X  jugendl_u_heranwachsende_14_bis_unter_21     362954
# 3  2019     M  jugendl_u_heranwachsende_14_bis_unter_21     268419
# 4  2019     W  jugendl_u_heranwachsende_14_bis_unter_21      86437
#
#    offenders_rel growth_rate_abs growth_rate_rel schluessel_crimes_on_rank_1  \
# 0           9178            n.a.            n.a.                      730000
# 1           3192            n.a.            n.a.                      *26*00
# 2           6317            n.a.            n.a.                      730000
# 3           9139           -2.48           -0.42                      730000
# 4           3190           -1.39           -0.05                      *26*00
#
#                                                              crimes_on_rank_1  \
# ...

# %%
df_overview_state = pd.concat([df_overview_state_14_to_under_16, df_overview_state_16_to_under_18, df_overview_state_18_to_under_21, df_overview_state_14_to_under_21])

df_overview_state = df_overview_state.reset_index()
df_overview_state = df_overview_state.drop(columns='index')

df_overview_state.tail()
# Out:
#     year sexus                                 age_group  offenders  \
# 55  2021     W  jugendl_u_heranwachsende_14_bis_unter_21      74246
# 56  2021     X  jugendl_u_heranwachsende_14_bis_unter_21     305754
# 57  2022     M  jugendl_u_heranwachsende_14_bis_unter_21     261324
# 58  2022     W  jugendl_u_heranwachsende_14_bis_unter_21      88823
# 59  2022     X  jugendl_u_heranwachsende_14_bis_unter_21     350147
#
#     offenders_rel growth_rate_abs growth_rate_rel schluessel_crimes_on_rank_1  \
# 55           2816           -6.62           -5.21                      *26*00
# 56           5602           -7.05           -5.34                      730000
# 57           9346           12.88           13.91                      220000
# 58           3394           19.63            20.5                      *26*00
# 59           6468           14.52           15.46                      220000
#
#                                                               crimes_on_rank_1  \
# ...

# %%
schema='public'
table_name = 'df_overview_state_2022_until_2018'
engine = get_engine()
print(engine)
# Out:
# Engine(postgresql://user:***@host/database)

# %%
if engine!=None:
    try:
        df_overview_state.to_sql(table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists='replace', # Drop the table before inserting new values 
                        schema=schema, # your class schema
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The df_overview_state_2022_until_2018 table was imported successfully.
