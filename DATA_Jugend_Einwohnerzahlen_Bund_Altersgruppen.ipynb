# %%
import pandas as pd
from sql_functions import *

# %%
pd.set_option('display.max_rows', 6000)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', None) # to show complete content of cell

# %%
def change_col_names(df):
    col_labels = df.columns.tolist()
    new_col_labels = [l.lower().replace(" ", "_").replace("ä", "ae").replace("ö", "oe").replace("ü", "ue").replace('\n', '_') for l in col_labels]
    df.columns = new_col_labels

# %%
einw_bund_altersgruppen_geschlecht = pd.read_excel("data/Bevoelkerungszahlen_EDA_Jugendkriminalitaet/einw_altersgr_geschlecht_bund_2022-2018.xlsx")

# %%
change_col_names(einw_bund_altersgruppen_geschlecht)

# %%
einw_bund_altersgruppen_geschlecht
# Out:
#    sexus    stichtag  year  kinder_10_bis_unter_12  kinder_12_bis_unter_14  \
# 0      M  31.12.2017  2018                  750663                  759916
# 1      W  31.12.2017  2018                  707164                  717794
# 2      X  31.12.2017  2018                 1457827                 1477710
# 3      M  31.12.2018  2019                  764922                  752947
# 4      W  31.12.2018  2019                  722953                  709736
# 5      X  31.12.2018  2019                 1487875                 1462683
# 6      M  31.12.2019  2020                  762729                  761433
# 7      W  31.12.2019  2020                  721310                  716935
# 8      X  31.12.2019  2020                 1484039                 1478368
# 9      M  31.12.2020  2021                  762929                  774238
# 10     W  31.12.2020  2021                  721245                  731512
# ...

# %%
schema='public'
table_name = 'einw_bund_altersgruppen_geschlecht_2022_until_2018'
engine = get_engine()
print(engine)
# Out:
# Engine(postgresql://user:***@host/database)

# %%
if engine!=None:
    try:
        einw_bund_altersgruppen_geschlecht.to_sql(table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists='replace', # Drop the table before inserting new values 
                        schema=schema, # your class schema
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The einw_bund_altersgruppen_geschlecht_2022_until_2018 table was imported successfully.
