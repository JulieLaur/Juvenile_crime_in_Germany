# %%
import pandas as pd
from sql_functions import *

# %%
pd.set_option('display.max_rows', 6000)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', None)

# %%
# %store -r df_overview_fed_states_14_to_under_16

# %%
# %store -r df_overview_fed_states_16_to_under_18

# %%
# %store -r df_overview_fed_states_18_to_under_21

# %%
# %store -r df_overview_fed_states_14_to_under_21

# %%
df_overview_fed_states_14_to_under_16.head()
# Out:
#           bundesland  year sexus                    age_group  offenders  \
# 0  Baden-Württemberg  2018     M  jugendliche_14_bis_unter_16       6585
# 1             Bayern  2018     M  jugendliche_14_bis_unter_16       6786
# 2             Berlin  2018     M  jugendliche_14_bis_unter_16       2881
# 3        Brandenburg  2018     M  jugendliche_14_bis_unter_16       1869
# 4             Bremen  2018     M  jugendliche_14_bis_unter_16        642
#
#    offenders_rel growth_rate_abs growth_rate_rel schluessel_crimes_on_rank_1  \
# 0           6007            n.a.            n.a.                      *26*00
# 1           5534            n.a.            n.a.                      730000
# 2          10002            n.a.            n.a.                      220000
# 3           8664            n.a.            n.a.                      220000
# 4          10819            n.a.            n.a.                      *26*00
#
# ...

# %%
df_overview_fed_states_16_to_under_18.head()
# Out:
#           bundesland  year sexus                    age_group  offenders  \
# 0  Baden-Württemberg  2018     M  jugendliche_16_bis_unter_18      10078
# 1             Bayern  2018     M  jugendliche_16_bis_unter_18      10604
# 2             Berlin  2018     M  jugendliche_16_bis_unter_18       3977
# 3        Brandenburg  2018     M  jugendliche_16_bis_unter_18       2469
# 4             Bremen  2018     M  jugendliche_16_bis_unter_18       1125
#
#    offenders_rel growth_rate_abs growth_rate_rel schluessel_crimes_on_rank_1  \
# 0           8600            n.a.            n.a.                      730000
# 1           7998            n.a.            n.a.                      730000
# 2          13427            n.a.            n.a.                      220000
# 3          11170            n.a.            n.a.                      730000
# 4          16922            n.a.            n.a.                      220000
#
# ...

# %%
df_overview_fed_states_18_to_under_21.head()
# Out:
#           bundesland  year sexus                       age_group  offenders  \
# 0  Baden-Württemberg  2018     M  heranwachsende_18_bis_unter_21      20122
# 1             Bayern  2018     M  heranwachsende_18_bis_unter_21      24065
# 2             Berlin  2018     M  heranwachsende_18_bis_unter_21       7941
# 3        Brandenburg  2018     M  heranwachsende_18_bis_unter_21       3910
# 4             Bremen  2018     M  heranwachsende_18_bis_unter_21       1934
#
#    offenders_rel growth_rate_abs growth_rate_rel schluessel_crimes_on_rank_1  \
# 0           9909            n.a.            n.a.                      730000
# 1          10521            n.a.            n.a.                      730000
# 2          15860            n.a.            n.a.                      220000
# 3          12308            n.a.            n.a.                      730000
# 4          15209            n.a.            n.a.                      220000
#
# ...

# %%
df_overview_fed_states_14_to_under_21.head()
# Out:
#           bundesland  year sexus                                 age_group  \
# 0  Baden-Württemberg  2018     M  jugendl_u_heranwachsende_14_bis_unter_21
# 1             Bayern  2018     M  jugendl_u_heranwachsende_14_bis_unter_21
# 2             Berlin  2018     M  jugendl_u_heranwachsende_14_bis_unter_21
# 3        Brandenburg  2018     M  jugendl_u_heranwachsende_14_bis_unter_21
# 4             Bremen  2018     M  jugendl_u_heranwachsende_14_bis_unter_21
#
#    offenders  offenders_rel growth_rate_abs growth_rate_rel  \
# 0      36785           8557            n.a.            n.a.
# 1      41455           8566            n.a.            n.a.
# 2      14799          13641            n.a.            n.a.
# 3       8248          10933            n.a.            n.a.
# 4       3701          14630            n.a.            n.a.
#
#   schluessel_crimes_on_rank_1  \
# 0                      730000
# 1                      730000
# 2                      220000
# ...

# %%
df_overview_fed_states = pd.concat([df_overview_fed_states_14_to_under_16, df_overview_fed_states_16_to_under_18, df_overview_fed_states_18_to_under_21, df_overview_fed_states_14_to_under_21])

df_overview_fed_states = df_overview_fed_states.reset_index()
df_overview_fed_states = df_overview_fed_states.drop(columns='index')
df_overview_fed_states
# Out:
#                  bundesland  year sexus  \
# 0         Baden-Württemberg  2018     M
# 1                    Bayern  2018     M
# 2                    Berlin  2018     M
# 3               Brandenburg  2018     M
# 4                    Bremen  2018     M
# 5                   Hamburg  2018     M
# 6                    Hessen  2018     M
# 7    Mecklenburg-Vorpommern  2018     M
# 8             Niedersachsen  2018     M
# 9       Nordrhein-Westfalen  2018     M
# 10          Rheinland-Pfalz  2018     M
# 11                 Saarland  2018     M
# 12                  Sachsen  2018     M
# 13           Sachsen-Anhalt  2018     M
# 14       Schleswig-Holstein  2018     M
# 15                Thüringen  2018     M
# 16        Baden-Württemberg  2018     W
# 17                   Bayern  2018     W
# 18                   Berlin  2018     W
# 19              Brandenburg  2018     W
# 20                   Bremen  2018     W
# 21                  Hamburg  2018     W
# ...

# %%
schema='public'
table_name = 'df_overview_fed_states_2022_until_2018'
engine = get_engine()
print(engine)
# Out:
# Engine(postgresql://user:***@host/database)

# %%
if engine!=None:
    try:
        df_overview_fed_states.to_sql(table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists='replace', # Drop the table before inserting new values 
                        schema=schema, # your class schema
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The df_overview_fed_states_2022_until_2018 table was imported successfully.
